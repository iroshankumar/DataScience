# %%
import warnings 
import warnings

# Code that triggers a specific warning

# Ignore a specific warning
warnings.filterwarnings("ignore")

# Code that triggers the specific warning but will be ignored

# Reset warnings to default behavior (optional)
warnings.resetwarnings()

# %%
import requests

# %%
import pandas as pd

# %% [markdown]
# ## getting data form websit and converting/saving it into csv.

# %%
url="https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Save the content of the response to a local CSV file
    with open("downloaded_data.csv", "wb") as f:
        f.write(response.content)
    print("CSV file downloaded successfully")
else:
    print("Failed to download CSV file. Status code:", response.status_code)

# Read the CSV file into a Pandas DataFrame
df = pd.read_csv("downloaded_data.csv")
# Out:
# CSV file downloaded successfully

# %% [markdown]
# # getting started with data analysis

# %%
df.shape #getting the shape of data
# Out:
# (891, 12)

# %% [markdown]
# ###  observations: we have 891 row and 12 col.

# %% [markdown]
# ### trying to get the overview of data

# %%
df.head() #we are using sample for getting over-view of data
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### observations :
#                     the data having 12 col.
#                     cabin is have some nan or null values.

# %%
df.info() #getting more information about the data and checking type of data every clm.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #### observations
# #### 1. from above we know that data have 11 col. and 891 rows
# #### 2. we have some missing datas in :-age ,cabin and embarked col.

# %%
df.isnull().sum()  #checking missing values in data
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### observations:
# ### Age , vabin and Embarked have Null values

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### observations

# %%
df.duplicated().sum()  #checking duplicates values in data
# Out:
# 0

# %% [markdown]
# ### observations: we don't have any duplicate data

# %%
df2=df
df2.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
#df2.drop(['Name'],axis=1,inplace=True)

# %%
df2.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 826          827         0       3                              Lam, Mr. Len
# 649          650         1       3           Stanley, Miss. Amy Zillah Elsie
# 302          303         0       3           Johnson, Mr. William Cahoone Jr
# 52            53         1       1  Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 489          490         1       3     Coutts, Master. Eden Leslie "Neville"
# 456          457         0       1                 Millet, Mr. Francis Davis
# 162          163         0       3                Bengtsson, Mr. John Viktor
# 764          765         0       3                    Eklund, Mr. Hans Linus
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 458          459         1       2                       Toomey, Miss. Ellen
#
#         Sex   Age  SibSp  Parch        Ticket     Fare Cabin Embarked
# 826    male   NaN      0      0          1601  56.4958   NaN        S
# 649  female  23.0      0      0      CA. 2314   7.5500   NaN        S
# 302    male  19.0      0      0          LINE   0.0000   NaN        S
# 52   female  49.0      1      0      PC 17572  76.7292   D33        C
# 489    male   9.0      1      1    C.A. 37671  15.9000   NaN        S
# 456    male  65.0      0      0         13509  26.5500   E38        S
# 162    male  26.0      0      0        347068   7.7750   NaN        S
# 764    male  16.0      0      0        347074   7.7750   NaN        S
# 172  female   1.0      1      1        347742  11.1333   NaN        S
# 458  female  50.0      0      0  F.C.C. 13531  10.5000   NaN        S

# %%
df2=df2.drop(['Name','Sex','Ticket','Cabin'],axis=1) #drop the object data from dataset

# %% [markdown]
# ## changeing the object into num to get better understanding between the dataset.

# %%
gender_mapping = {'male': 0, 'female': 1}
df2['Sex'] = df['Sex'].map(gender_mapping)
df2.sample(50)
# Out:
#      PassengerId  Survived  Pclass    Age  SibSp  Parch      Fare Embarked  \
# 365          366         0       3  30.00      0      0    7.2500        S
# 64            65         0       1    NaN      0      0   27.7208        C
# 319          320         1       1  40.00      1      1  134.5000        C
# 833          834         0       3  23.00      0      0    7.8542        S
# 154          155         0       3    NaN      0      0    7.3125        S
# 309          310         1       1  30.00      0      0   56.9292        C
# 571          572         1       1  53.00      2      0   51.4792        S
# 486          487         1       1  35.00      1      0   90.0000        S
# 46            47         0       3    NaN      1      0   15.5000        Q
# 305          306         1       1   0.92      1      2  151.5500        S
# 783          784         0       3    NaN      1      2   23.4500        S
# 161          162         1       2  40.00      0      0   15.7500        S
# 625          626         0       1  61.00      0      0   32.3208        S
# 663          664         0       3  36.00      0      0    7.4958        S
# 673          674         1       2  31.00      0      0   13.0000        S
# 449          450         1       1  52.00      0      0   30.5000        S
# 681          682         1       1  27.00      0      0   76.7292        C
# 69            70         0       3  26.00      2      0    8.6625        S
# 517          518         0       3    NaN      0      0   24.1500        Q
# 355          356         0       3  28.00      0      0    9.5000        S
# 9             10         1       2  14.00      1      0   30.0708        C
# 837          838         0       3    NaN      0      0    8.0500        S
# 114          115         0       3  17.00      0      0   14.4583        C
# 372          373         0       3  19.00      0      0    8.0500        S
# 254          255         0       3  41.00      0      2   20.2125        S
# 395          396         0       3  22.00      0      0    7.7958        S
# 250          251         0       3    NaN      0      0    7.2500        S
# 675          676         0       3  18.00      0      0    7.7750        S
# 534          535         0       3  30.00      0      0    8.6625        S
# 888          889         0       3    NaN      1      2   23.4500        S
# 275          276         1       1  63.00      1      0   77.9583        S
# 174          175         0       1  56.00      0      0   30.6958        C
# 338          339         1       3  45.00      0      0    8.0500        S
# 20            21         0       2  35.00      0      0   26.0000        S
# 99           100         0       2  34.00      1      0   26.0000        S
# 485          486         0       3    NaN      3      1   25.4667        S
# 787          788         0       3   8.00      4      1   29.1250        Q
# 223          224         0       3    NaN      0      0    7.8958        S
# 792          793         0       3    NaN      8      2   69.5500        S
# 93            94         0       3  26.00      1      2   20.5750        S
# 113          114         0       3  20.00      1      0    9.8250        S
# 304          305         0       3    NaN      0      0    8.0500        S
# 218          219         1       1  32.00      0      0   76.2917        C
# 171          172         0       3   4.00      4      1   29.1250        Q
# 755          756         1       2   0.67      1      1   14.5000        S
# 347          348         1       3    NaN      1      0   16.1000        S
# 199          200         0       2  24.00      0      0   13.0000        S
# 228          229         0       2  18.00      0      0   13.0000        S
# 126          127         0       3    NaN      0      0    7.7500        Q
# 736          737         0       3  48.00      1      3   34.3750        S
#
#      Sex
# 365    0
# 64     0
# 319    1
# 833    0
# 154    0
# 309    1
# 571    1
# 486    1
# 46     0
# 305    0
# 783    0
# 161    1
# 625    0
# 663    0
# 673    0
# 449    0
# 681    0
# 69     0
# 517    0
# 355    0
# 9      1
# 837    0
# 114    1
# 372    0
# 254    1
# 395    0
# 250    0
# 675    0
# 534    1
# 888    1
# 275    1
# 174    0
# 338    0
# 20     0
# 99     0
# 485    1
# 787    0
# 223    0
# 792    1
# 93     0
# 113    1
# 304    0
# 218    1
# 171    0
# 755    0
# 347    1
# 199    1
# 228    0
# 126    0
# 736    1

# %%
Embarked_mapping = {'S': 1, 'Q': 2, 'C': 3}
df2['Embarked'] = df['Embarked'].map(Embarked_mapping)
df2
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Embarked  Sex
# 0              1         0       3  22.0      1      0   7.2500       1.0    0
# 1              2         1       1  38.0      1      0  71.2833       3.0    1
# 2              3         1       3  26.0      0      0   7.9250       1.0    1
# 3              4         1       1  35.0      1      0  53.1000       1.0    1
# 4              5         0       3  35.0      0      0   8.0500       1.0    0
# ..           ...       ...     ...   ...    ...    ...      ...       ...  ...
# 886          887         0       2  27.0      0      0  13.0000       1.0    0
# 887          888         1       1  19.0      0      0  30.0000       1.0    1
# 888          889         0       3   NaN      1      2  23.4500       1.0    1
# 889          890         1       1  26.0      0      0  30.0000       3.0    0
# 890          891         0       3  32.0      0      0   7.7500       2.0    0
#
# [891 rows x 9 columns]

# %% [markdown]
# ## checking the relation and representiong data into Mathematical

# %%
df2.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
# Embarked       -0.013166  0.169718 -0.164681  0.032565 -0.068900 -0.040449
# Sex            -0.042939  0.543351 -0.131900 -0.093254  0.114631  0.245489
#
#                  Fare  Embarked       Sex
# PassengerId  0.012658 -0.013166 -0.042939
# Survived     0.257307  0.169718  0.543351
# Pclass      -0.549500 -0.164681 -0.131900
# Age          0.096067  0.032565 -0.093254
# SibSp        0.159651 -0.068900  0.114631
# Parch        0.216225 -0.040449  0.245489
# Fare         1.000000  0.226311  0.182333
# Embarked     0.226311  1.000000  0.110320
# Sex          0.182333  0.110320  1.000000

# %%
pwd
# Out:
# 'C:\\Users\\HISPL\\Desktop\\Day4'

# %% [markdown]
# # EDA on data sets

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # categorical Datas

# %%
df2
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Embarked  Sex
# 0              1         0       3  22.0      1      0   7.2500       1.0    0
# 1              2         1       1  38.0      1      0  71.2833       3.0    1
# 2              3         1       3  26.0      0      0   7.9250       1.0    1
# 3              4         1       1  35.0      1      0  53.1000       1.0    1
# 4              5         0       3  35.0      0      0   8.0500       1.0    0
# ..           ...       ...     ...   ...    ...    ...      ...       ...  ...
# 886          887         0       2  27.0      0      0  13.0000       1.0    0
# 887          888         1       1  19.0      0      0  30.0000       1.0    1
# 888          889         0       3   NaN      1      2  23.4500       1.0    1
# 889          890         1       1  26.0      0      0  30.0000       3.0    0
# 890          891         0       3  32.0      0      0   7.7500       2.0    0
#
# [891 rows x 9 columns]

# %%
sns.histplot(df2['Survived'])
plt.show()

# %%
sns.countplot(data=df2,x='Pclass',palette='Set2')
plt.show()

# %%
sns.countplot(df2,x='Embarked',palette='Set3')
plt.show()

# %%
sns.distplot(df2['Age'])
# Out:
# C:\Users\HISPL\AppData\Local\Temp\ipykernel_12956\176412087.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df2['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
sns.distplot(df2['SibSp'])
plt.show()
# Out:
# C:\Users\HISPL\AppData\Local\Temp\ipykernel_12956\1818717062.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['SibSp'])

# %%
sns.distplot(df2['Parch'])
plt.show()
# Out:
# C:\Users\HISPL\AppData\Local\Temp\ipykernel_12956\1487363048.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['Parch'])

# %%
df2
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Embarked  Sex
# 0              1         0       3  22.0      1      0   7.2500       1.0    0
# 1              2         1       1  38.0      1      0  71.2833       3.0    1
# 2              3         1       3  26.0      0      0   7.9250       1.0    1
# 3              4         1       1  35.0      1      0  53.1000       1.0    1
# 4              5         0       3  35.0      0      0   8.0500       1.0    0
# ..           ...       ...     ...   ...    ...    ...      ...       ...  ...
# 886          887         0       2  27.0      0      0  13.0000       1.0    0
# 887          888         1       1  19.0      0      0  30.0000       1.0    1
# 888          889         0       3   NaN      1      2  23.4500       1.0    1
# 889          890         1       1  26.0      0      0  30.0000       3.0    0
# 890          891         0       3  32.0      0      0   7.7500       2.0    0
#
# [891 rows x 9 columns]

# %%
df2['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df2['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### df2['SibSp'].value_counts().plot(kind='pie',autopct='%.2f')
# #### plt.show()
# #### df2['Parch'].value_counts().plot(kind='pie',autopct='%.2f')
# #### plt.show()
# #### df2['Fare'].value_counts().plot(kind='pie',autopct='%.2f')
# #### plt.show()

# %%
df2['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %% [markdown]
# # Observations
# - # only 38.28 % survived and 61.62 % not survived
# - # Passangers class :55.11% was treveling in 3rd class ,24.24% was in 1st class and rest in 2nd class
# - # Embarked : Southampton 70%, Cherbourg 20% , and Queenstown 10%
# - # Age : maximum passangers was between 18 to 60 years
# - # siblings and spouse : around 70% passangers not trevelin with there siblings or spouse
# - # Parents and child : more then 60% passangers are treveling alone

# %%
df2
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Embarked  Sex
# 0              1         0       3  22.0      1      0   7.2500       1.0    0
# 1              2         1       1  38.0      1      0  71.2833       3.0    1
# 2              3         1       3  26.0      0      0   7.9250       1.0    1
# 3              4         1       1  35.0      1      0  53.1000       1.0    1
# 4              5         0       3  35.0      0      0   8.0500       1.0    0
# ..           ...       ...     ...   ...    ...    ...      ...       ...  ...
# 886          887         0       2  27.0      0      0  13.0000       1.0    0
# 887          888         1       1  19.0      0      0  30.0000       1.0    1
# 888          889         0       3   NaN      1      2  23.4500       1.0    1
# 889          890         1       1  26.0      0      0  30.0000       3.0    0
# 890          891         0       3  32.0      0      0   7.7500       2.0    0
#
# [891 rows x 9 columns]

# %%
df3=df[['Cabin']]
df3
# Out:
#     Cabin
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# ..    ...
# 886   NaN
# 887   B42
# 888   NaN
# 889  C148
# 890   NaN
#
# [891 rows x 1 columns]

# %%
# Replace NaN with 0 and non-NaN with 1 in the entire DataFrame (in place)
df3.fillna(0, inplace=True)
df3[df3 != 0] = 1

print(df3)
# Out:
#     Cabin
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
# ..    ...
# 886     0
# 887     1
# 888     0
# 889     1
# 890     0
#
# [891 rows x 1 columns]
# C:\Users\HISPL\AppData\Local\Temp\ipykernel_12956\748136013.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.fillna(0, inplace=True)
# C:\Users\HISPL\AppData\Local\Temp\ipykernel_12956\748136013.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3[df3 != 0] = 1
# C:\Users\HISPL\AppData\Local\Temp\ipykernel_12956\748136013.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3[df3 != 0] = 1

# %%
df3
# Out:
#     Cabin
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
# ..    ...
# 886     0
# 887     1
# 888     0
# 889     1
# 890     0
#
# [891 rows x 1 columns]

# %%
df4=pd.concat([df2,df3],axis=1)

# %%
df4.head(1)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare  Embarked  Sex  \
# 0            1         0       3  22.0      1      0  7.25       1.0    0
#
#   Cabin
# 0     0

# %%
#df4[['PassengerId'],['Survived']]
#df[['width’, 'length’, 'species']]

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df4.head(1)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare  Embarked  Sex  \
# 0            1         0       3  22.0      1      0  7.25       1.0    0
#
#   Cabin
# 0     0

# %%
df5=df[['PassengerId','Name','Fare' ]]
df5
# Out:
#      PassengerId                                               Name     Fare
# 0              1                            Braund, Mr. Owen Harris   7.2500
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2              3                             Heikkinen, Miss. Laina   7.9250
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4              5                           Allen, Mr. William Henry   8.0500
# ..           ...                                                ...      ...
# 886          887                              Montvila, Rev. Juozas  13.0000
# 887          888                       Graham, Miss. Margaret Edith  30.0000
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  23.4500
# 889          890                              Behr, Mr. Karl Howell  30.0000
# 890          891                                Dooley, Mr. Patrick   7.7500
#
# [891 rows x 3 columns]

# %%
df6=df4[['Pclass' , 'Sex', 'Age','SibSp','Parch', 'Embarked','Cabin','Fare']]
df6
# Out:
#      Pclass  Sex   Age  SibSp  Parch  Embarked Cabin     Fare
# 0         3    0  22.0      1      0       1.0     0   7.2500
# 1         1    1  38.0      1      0       3.0     1  71.2833
# 2         3    1  26.0      0      0       1.0     0   7.9250
# 3         1    1  35.0      1      0       1.0     1  53.1000
# 4         3    0  35.0      0      0       1.0     0   8.0500
# ..      ...  ...   ...    ...    ...       ...   ...      ...
# 886       2    0  27.0      0      0       1.0     0  13.0000
# 887       1    1  19.0      0      0       1.0     1  30.0000
# 888       3    1   NaN      1      2       1.0     0  23.4500
# 889       1    0  26.0      0      0       3.0     1  30.0000
# 890       3    0  32.0      0      0       2.0     0   7.7500
#
# [891 rows x 8 columns]

# %%
df7=pd.concat([df5,df6],axis=1)
df7
# Out:
#      PassengerId                                               Name     Fare  \
# 0              1                            Braund, Mr. Owen Harris   7.2500
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2              3                             Heikkinen, Miss. Laina   7.9250
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4              5                           Allen, Mr. William Henry   8.0500
# ..           ...                                                ...      ...
# 886          887                              Montvila, Rev. Juozas  13.0000
# 887          888                       Graham, Miss. Margaret Edith  30.0000
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  23.4500
# 889          890                              Behr, Mr. Karl Howell  30.0000
# 890          891                                Dooley, Mr. Patrick   7.7500
#
#      Pclass  Sex   Age  SibSp  Parch  Embarked Cabin     Fare
# 0         3    0  22.0      1      0       1.0     0   7.2500
# 1         1    1  38.0      1      0       3.0     1  71.2833
# 2         3    1  26.0      0      0       1.0     0   7.9250
# 3         1    1  35.0      1      0       1.0     1  53.1000
# 4         3    0  35.0      0      0       1.0     0   8.0500
# ..      ...  ...   ...    ...    ...       ...   ...      ...
# 886       2    0  27.0      0      0       1.0     0  13.0000
# 887       1    1  19.0      0      0       1.0     1  30.0000
# 888       3    1   NaN      1      2       1.0     0  23.4500
# 889       1    0  26.0      0      0       3.0     1  30.0000
# 890       3    0  32.0      0      0       2.0     0   7.7500
#
# [891 rows x 11 columns]

# %%
df7.to_csv('Titanic',index=False)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E668-A98E
#
#  Directory of C:\Users\HISPL\Desktop\Day4
#
# 25-01-2024  12:57    <DIR>          .
# 25-01-2024  10:15    <DIR>          ..
# 25-01-2024  10:29    <DIR>          .ipynb_checkpoints
# 25-01-2024  12:58            60,302 downloaded_data.csv
# 25-01-2024  12:39            34,554 making profile dashboard of a dataset.ipynb
# 25-01-2024  12:37         2,803,518 output.html
# 25-01-2024  12:58            58,280 Titanic
# 25-01-2024  12:38         2,803,518 Titanic Report.html
# 25-01-2024  12:57           368,136 titanic.ipynb
#                6 File(s)      6,128,308 bytes
#                3 Dir(s)  437,890,277,376 bytes free
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=6>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# C:\Users\HISPL\AppData\Roaming\Python\Python311\site-packages\visions\utils\monkeypatches\imghdr_patch.py:2: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   from imghdr import tests
# C:\Users\HISPL\AppData\Roaming\Python\Python311\site-packages\wordcloud\wordcloud.py:35: ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\HISPL\\AppData\\Roaming\\Python\\Python311\\site-packages\\wordcloud\\stopwords' mode='r' encoding='cp1252'>
#   STOPWORDS = set(map(str.strip, open(os.path.join(FILE, 'stopwords')).readlines()))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\HISPL\AppData\Local\Temp\ipykernel_12956\4209343599.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# C:\ProgramData\anaconda3\Lib\site-packages\ipywidgets\widgets\widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\ProgramData\anaconda3\Lib\site-packages\ipywidgets\widgets\widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\ProgramData\anaconda3\Lib\site-packages\ipywidgets\widgets\widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\HISPL\AppData\Roaming\Python\Python311\site-packages\htmlmin\main.py:28: DeprecationWarning: 'cgi' is deprecated and slated for removal in Python 3.13
#   import cgi
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.scatter(x="Survived",y='Fare')
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E668-A98E
#
#  Directory of C:\Users\HISPL\Desktop\Day4
#
# 25-01-2024  12:57    <DIR>          .
# 25-01-2024  10:15    <DIR>          ..
# 25-01-2024  10:29    <DIR>          .ipynb_checkpoints
# 25-01-2024  12:58            60,302 downloaded_data.csv
# 25-01-2024  12:39            34,554 making profile dashboard of a dataset.ipynb
# 25-01-2024  12:58         4,814,357 output.html
# 25-01-2024  12:58            58,280 Titanic
# 25-01-2024  12:38         2,803,518 Titanic Report.html
# 25-01-2024  12:57           368,136 titanic.ipynb
#                6 File(s)      8,139,147 bytes
#                3 Dir(s)  437,888,462,848 bytes free
# C:\ProgramData\anaconda3\Lib\threading.py:979: ResourceWarning: unclosed file <_io.BufferedWriter name=6>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\ProgramData\anaconda3\Lib\threading.py:979: ResourceWarning: unclosed file <_io.BufferedReader name=7>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\ProgramData\anaconda3\Lib\threading.py:979: ResourceWarning: unclosed file <_io.BufferedReader name=8>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
